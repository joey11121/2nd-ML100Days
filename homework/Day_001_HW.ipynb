# %% [markdown]
# 作業1:
# kaggle data 標題：Google Play Store Apps 網址：https://www.kaggle.com/lava18/google-play-store-apps
#
# 1. 可以藉由這筆資料做APP市場分析,比如哪一個領域的APP使用人數平均上來說比較多
#
# 2. 從Google Play Store進行網頁抓取得來的
#
# 3. 屬於結構化資料型態,因為此筆數據含有表格,而且每個欄位都有其名稱
#
# 4. 比如要研究用戶對於該APP的評價與使用者評價數量的相關性時,可以使用線性回歸的方式去檢驗rating項目和Installs項目的關係
#
# 作業2:
# 1. 車隊需要客源才能賺錢,我們需要的是客源的位置,用數據檢視哪一個場所的客戶會需要以計程車作為交通工具;
#    除此之外,若是乘客搭乘距離越遠,所需支付的車資就越高,所以我們也需要檢視哪個地方的乘客需要乘坐比較長
#    的距離;還有,找出尖峰時間也是很重要的
#
# 2. 計程車可以發出訊號到公司裡面的主機顯示即時位置,當乘客上車時,我們可以紀錄每一趟車程的起始位置和時間,下車時則紀錄終點位置和時間,有了起    點就可以計算乘車距離,時間的數據可以觀察客人經常上車的巔峰時間
#
# 3. 蒐集來的資料屬於非結構化資料型態,因為我們蒐集的資料含有地點名稱,距離等等,但是無固定表格
#
# 4. 我們可以將蒐集來的起始位置做一些分類,比如像是車站,機場,飯店......等等,然後分類後做一個表格出來,
#    整理過後我們就可以比較哪一種地方的客源是最多的,然後對這些資料進行乘車平均距離計算;另外將時間和地
#    點使用線性回歸做相關性的分析,以整理某個地點在某個時間有巔峰客源,藉由以上方式,就可以統整出客源的地
#    點時間與乘車距離等條件較佳的地點

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y, yp):
    mse = MSE = sum((y-yp)**2) / len(y)
    return mse

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# %%
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 290.986
# The Mean absolute error is 13.618
